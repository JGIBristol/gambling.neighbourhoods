# %% [markdown]
# # Gambling Clustering using python hdbscan
#
# We are going to read the data and perform clustering using the python hdbscan library.

# %%
import hdbscan
import pandas as pd
import numpy as np



# Load the coordinate data
data = pd.read_csv('data/bristol_coordinates.csv')
